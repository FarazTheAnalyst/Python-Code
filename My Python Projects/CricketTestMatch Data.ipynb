# %% [markdown]
# https://www.espncricinfo.com/records/highest-career-batting-average-282910

# %%
# import pandas as pd

# %%
import pandas as pd

# %%
#import csv

# %%
df = pd.read_csv(r"C:\Users\Dell\Downloads\CricketTestMatchData.csv")
df.head()
# Out:
#              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0  DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1    HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2    AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4   RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
#
#       SR  100  50  0   4s  6s
# 0   58.6   29  13  7  626   6
# 1  91.76    4   7  1  141  23
# 2  55.68    5   4  2  186   5
# 3  54.48    7  11  1  246  11
# 4  54.48    7  11  1  246  11

# %%
#rename Multiples Columns in a list

# %%
df = df.rename(columns = {"Mat":"Match","NO":"Not_Outs", "HS":"Highest_inns_score", "BF":"Balls_Faced",
                          "SR":"Batting_Strike_Rate"})

df.head()
# Out:
#              Player       Span  Match  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948     52    80        10  6996
# 1    HC Brook (ENG)  2022-2023     12    20         1  1181
# 2    AC Voges (AUS)  2015-2016     20    31         7  1485
# 3   RG Pollock (SA)  1963-1970     23    41         4  2256
# 4   RG Pollock (SA)  1963-1970     23    41         4  2256
#
#   Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626
# 1                186  62.15        1287               91.76    4   7  1  141
# 2               269*  61.87        2667               55.68    5   4  2  186
# 3                274  60.97       1707+               54.48    7  11  1  246
# 4                274  60.97       1707+               54.48    7  11  1  246
#
#    6s
# 0   6
# 1  23
# 2   5
# 3  11
# 4  11

# %%
#Check NULL values

# %%
df.isnull().sum()
# Out:
# Player                 0
# Span                   0
# Match                  0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_inns_score     0
# Ave                    0
# Balls_Faced            3
# Batting_Strike_Rate    3
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Match                  False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_inns_score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df["Balls_Faced"].isna()==1]
# Out:
#              Player       Span  Match  Inns  Not_Outs  Runs  \
# 9    ED Weekes (WI)  1948-1958     48    81         5  4455
# 16  CL Walcott (WI)  1948-1960     44    74         7  3798
# 17  CL Walcott (WI)  1948-1960     44    74         7  3798
#
#    Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0   4s  \
# 9                 207  58.61         NaN                 NaN   15  19  6  258
# 16                220  56.68         NaN                 NaN   15  14  1  107
# 17                220  56.68         NaN                 NaN   15  14  1  107
#
#     6s
# 9    2
# 16  11
# 17  11

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df["Batting_Strike_Rate"] = df["Batting_Strike_Rate"].fillna(0)

# %%
df[df["Player"]=="ED Weekes (WI)"]
# Out:
#            Player       Span  Match  Inns  Not_Outs  Runs Highest_inns_score  \
# 9  ED Weekes (WI)  1948-1958     48    81         5  4455                207
#
#      Ave Balls_Faced Batting_Strike_Rate  100  50  0   4s  6s
# 9  58.61           0                   0   15  19  6  258   2

# %%
df[df["Player"]=="CL Walcott (WI)"]
# Out:
#              Player       Span  Match  Inns  Not_Outs  Runs  \
# 16  CL Walcott (WI)  1948-1960     44    74         7  3798
# 17  CL Walcott (WI)  1948-1960     44    74         7  3798
#
#    Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0   4s  \
# 16                220  56.68           0                   0   15  14  1  107
# 17                220  56.68           0                   0   15  14  1  107
#
#     6s
# 16  11
# 17  11

# %%
df[df=="-"].count()
# Out:
# Player                 0
# Span                   0
# Match                  0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_inns_score     0
# Ave                    0
# Balls_Faced            1
# Batting_Strike_Rate    1
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df.replace("-", 0, inplace=True)

# %%
df[df=="-"].count()
# Out:
# Player                 0
# Span                   0
# Match                  0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_inns_score     0
# Ave                    0
# Balls_Faced            0
# Batting_Strike_Rate    0
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               66 non-null     object
#  1   Span                 66 non-null     object
#  2   Match                66 non-null     int64
#  3   Inns                 66 non-null     int64
#  4   Not_Outs             66 non-null     int64
#  5   Runs                 66 non-null     int64
#  6   Highest_inns_score   66 non-null     object
#  7   Ave                  66 non-null     float64
#  8   Balls_Faced          66 non-null     object
#  9   Batting_Strike_Rate  66 non-null     object
#  10  100                  66 non-null     int64
#  11  50                   66 non-null     int64
#  12  0                    66 non-null     int64
#  13  4s                   66 non-null     int64
#  14  6s                   66 non-null     int64
# ...

# %%
#drop duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 66, dtype: bool

# %%
df[df["Player"].duplicated()==1]
# Out:
#                  Player       Span  Match  Inns  Not_Outs  Runs  \
# 4       RG Pollock (SA)  1963-1970     23    41         4  2256
# 12       GS Sobers (WI)  1954-1974     93   160        21  8032
# 17      CL Walcott (WI)  1948-1960     44    74         7  3798
# 59  TT Samaraweera (SL)  2001-2013     81   132        20  5462
#
#    Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 4                 274  60.97       1707+               54.48    7  11   1
# 12               365*  57.78       4063+               53.58   26  30  12
# 17                220  56.68           0                   0   15  14   1
# 59                231  48.76       11641               46.92   14  30  11
#
#      4s  6s
# 4   246  11
# 12  593  32
# 17  107  11
# 59  633   7

# %%
df[df["Player"].isin(["RG Pollock (SA)", "GS Sobers (WI)", "CL Walcott (WI)", "TT Samaraweera (SL)"])]
# Out:
#                  Player       Span  Match  Inns  Not_Outs  Runs  \
# 3       RG Pollock (SA)  1963-1970     23    41         4  2256
# 4       RG Pollock (SA)  1963-1970     23    41         4  2256
# 11       GS Sobers (WI)  1954-1974     93   160        21  8032
# 12       GS Sobers (WI)  1954-1974     93   160        21  8032
# 16      CL Walcott (WI)  1948-1960     44    74         7  3798
# 17      CL Walcott (WI)  1948-1960     44    74         7  3798
# 58  TT Samaraweera (SL)  2001-2013     81   132        20  5462
# 59  TT Samaraweera (SL)  2001-2013     81   132        20  5462
#
#    Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 3                 274  60.97       1707+               54.48    7  11   1
# 4                 274  60.97       1707+               54.48    7  11   1
# 11               365*  57.78       4063+               53.58   26  30  12
# 12               365*  57.78       4063+               53.58   26  30  12
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 5     False
#       ...
# 61    False
# 62    False
# 63    False
# 64    False
# 65    False
# Length: 62, dtype: bool

# %%
df[df["Player"].isin(["RG Pollock (SA)", "GS Sobers (WI)", "CL Walcott (WI)", "TT Samaraweera (SL)"])]
# Out:
#                  Player       Span  Match  Inns  Not_Outs  Runs  \
# 3       RG Pollock (SA)  1963-1970     23    41         4  2256
# 11       GS Sobers (WI)  1954-1974     93   160        21  8032
# 16      CL Walcott (WI)  1948-1960     44    74         7  3798
# 58  TT Samaraweera (SL)  2001-2013     81   132        20  5462
#
#    Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50   0  \
# 3                 274  60.97       1707+               54.48    7  11   1
# 11               365*  57.78       4063+               53.58   26  30  12
# 16                220  56.68           0                   0   15  14   1
# 58                231  48.76       11641               46.92   14  30  11
#
#      4s  6s
# 3   246  11
# 11  593  32
# 16  107  11
# 58  633   7

# %%
#Split up Span into start and end date

# %%
df["Span"].str.split("-")
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 5     [1930, 1954]
#           ...
# 61    [1965, 1981]
# 62    [2002, 2014]
# 63    [1924, 1934]
# 64    [1930, 1938]
# 65    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df["Rookie_Year"] = df["Span"].str.split("-").str.get(0)

# %%
df["Final_Year"] = df["Span"].str.split("-").str.get(1)

# %%
df.head()
# Out:
#              Player       Span  Match  Inns  Not_Outs  Runs  \
# 0  DG Bradman (AUS)  1928-1948     52    80        10  6996
# 1    HC Brook (ENG)  2022-2023     12    20         1  1181
# 2    AC Voges (AUS)  2015-2016     20    31         7  1485
# 3   RG Pollock (SA)  1963-1970     23    41         4  2256
# 5   GA Headley (WI)  1930-1954     22    40         4  2190
#
#   Highest_inns_score    Ave Balls_Faced Batting_Strike_Rate  100  50  0   4s  \
# 0                334  99.94       9800+                58.6   29  13  7  626
# 1                186  62.15        1287               91.76    4   7  1  141
# 2               269*  61.87        2667               55.68    5   4  2  186
# 3                274  60.97       1707+               54.48    7  11  1  246
# 5               270*  60.83        416+                  56   10   5  2  104
#
#    6s Rookie_Year Final_Year
# 0   6        1928       1948
# 1  23        2022       2023
# 2   5        2015       2016
# ...

# %%
#Drop Span Column

# %%
df.drop(["Span"], axis=1, inplace=True)

# %%
df.head()
# Out:
#              Player  Match  Inns  Not_Outs  Runs Highest_inns_score    Ave  \
# 0  DG Bradman (AUS)     52    80        10  6996                334  99.94
# 1    HC Brook (ENG)     12    20         1  1181                186  62.15
# 2    AC Voges (AUS)     20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)     23    41         4  2256                274  60.97
# 5   GA Headley (WI)     22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year
# 0       9800+                58.6   29  13  7  626   6        1928       1948
# 1        1287               91.76    4   7  1  141  23        2022       2023
# 2        2667               55.68    5   4  2  186   5        2015       2016
# 3       1707+               54.48    7  11  1  246  11        1963       1970
# 5        416+                  56   10   5  2  104   1        1930       1954

# %%
#Question -> Split up the Country From Player

# %%
df["Player"].str.split("(")
# Out:
# 0      [DG Bradman , AUS)]
# 1        [HC Brook , ENG)]
# 2        [AC Voges , AUS)]
# 3       [RG Pollock , SA)]
# 5       [GA Headley , WI)]
#               ...
# 61     [KD Walters , AUS)]
# 62    [GC Smith , ICC/SA)]
# 63    [WH Ponsford , AUS)]
# 64      [SJ McCabe , AUS)]
# 65     [DR Jardine , ENG)]
# Name: Player, Length: 62, dtype: object

# %%
df["Country"] = df["Player"].str.split("(").str.get(1)
df.head()
# Out:
#              Player  Match  Inns  Not_Outs  Runs Highest_inns_score    Ave  \
# 0  DG Bradman (AUS)     52    80        10  6996                334  99.94
# 1    HC Brook (ENG)     12    20         1  1181                186  62.15
# 2    AC Voges (AUS)     20    31         7  1485               269*  61.87
# 3   RG Pollock (SA)     23    41         4  2256                274  60.97
# 5   GA Headley (WI)     22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year  \
# 0       9800+                58.6   29  13  7  626   6        1928       1948
# 1        1287               91.76    4   7  1  141  23        2022       2023
# 2        2667               55.68    5   4  2  186   5        2015       2016
# 3       1707+               54.48    7  11  1  246  11        1963       1970
# 5        416+                  56   10   5  2  104   1        1930       1954
#
#   Country
# 0    AUS)
# 1    ENG)
# 2    AUS)
# ...

# %%
df["Country"] = df["Country"].str.split(")").str.get(0)

# %%
df["Player"] = df["Player"].str.split("(").str.get(0)
df["Player"]
# Out:
# 0      DG Bradman
# 1        HC Brook
# 2        AC Voges
# 3      RG Pollock
# 5      GA Headley
#           ...
# 61     KD Walters
# 62       GC Smith
# 63    WH Ponsford
# 64      SJ McCabe
# 65     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
df.head()
# Out:
#         Player  Match  Inns  Not_Outs  Runs Highest_inns_score    Ave  \
# 0  DG Bradman      52    80        10  6996                334  99.94
# 1    HC Brook      12    20         1  1181                186  62.15
# 2    AC Voges      20    31         7  1485               269*  61.87
# 3  RG Pollock      23    41         4  2256                274  60.97
# 5  GA Headley      22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year  \
# 0       9800+                58.6   29  13  7  626   6        1928       1948
# 1        1287               91.76    4   7  1  141  23        2022       2023
# 2        2667               55.68    5   4  2  186   5        2015       2016
# 3       1707+               54.48    7  11  1  246  11        1963       1970
# 5        416+                  56   10   5  2  104   1        1930       1954
#
#   Country
# 0     AUS
# 1     ENG
# 2     AUS
# 3      SA
# 5      WI

# %%
#Second Method

# %%
#player_pattern = r"(\w+)\s"
#df["Player"].str.extract(player_pattern)

#ountry_pattern = r"\((\w+)\)"
#df["Country"].str.extract()**/

# %%
#Change Data types

# %%
df.dtypes
# Out:
# Player                  object
# Match                    int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_inns_score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate     object
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df[["Highest_inn_score", "Out_Notout"]] = df["Highest_inns_score"].str.split("*", expand=True)
df["Out_Notout"].fillna("Out", inplace = True)
df.head()
# Out:
#         Player  Match  Inns  Not_Outs  Runs Highest_inns_score    Ave  \
# 0  DG Bradman      52    80        10  6996                334  99.94
# 1    HC Brook      12    20         1  1181                186  62.15
# 2    AC Voges      20    31         7  1485               269*  61.87
# 3  RG Pollock      23    41         4  2256                274  60.97
# 5  GA Headley      22    40         4  2190               270*  60.83
#
#   Balls_Faced Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year  \
# 0       9800+                58.6   29  13  7  626   6        1928       1948
# 1        1287               91.76    4   7  1  141  23        2022       2023
# 2        2667               55.68    5   4  2  186   5        2015       2016
# 3       1707+               54.48    7  11  1  246  11        1963       1970
# 5        416+                  56   10   5  2  104   1        1930       1954
#
#   Country Highest_inn_score Out_Notout
# ...

# %%
df["Out_Notout"] = df["Out_Notout"].apply(lambda x: x.replace("", "Notout") if x == "" else x)

# %%
df["Highest_inn_score"] = pd.to_numeric(df["Highest_inn_score"])
df["Batting_Strike_Rate"] = pd.to_numeric(df["Batting_Strike_Rate"])

# %%
df.dtypes
# Out:
# Player                  object
# Match                    int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_inns_score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# Highest_inn_score        int64
# Out_Notout              object
# dtype: object

# %%
##QUESTION See if you can fix Rookie_Year and Final_Year

# %%
df = df.astype({"Rookie_Year":"int", "Final_Year":"int"})

# %%
df.dtypes
# Out:
# Player                  object
# Match                    int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_inns_score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# Highest_inn_score        int64
# Out_Notout              object
# dtype: object

# %%
df["Balls_Faced"] = df["Balls_Faced"].str.split("+").str.get(0)
df["Balls_Faced"]
# Out:
# 0      9800
# 1      1287
# 2      2667
# 3      1707
# 5       416
#       ...
# 61     8662
# 62    15525
# 63     3118
# 64     3217
# 65     2110
# Name: Balls_Faced, Length: 62, dtype: object

# %%
df.dtypes
# Out:
# Player                  object
# Match                    int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_inns_score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# Highest_inn_score        int64
# Out_Notout              object
# dtype: object

# %%
df[df["Balls_Faced"].isna()==1]
# Out:
#              Player  Match  Inns  Not_Outs  Runs Highest_inns_score    Ave  \
# 9        ED Weekes      48    81         5  4455                207  58.61
# 16      CL Walcott      44    74         7  3798                220  56.68
# 57  Hon.FS Jackson      20    33         4  1415               144*  48.79
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 9          NaN                  0.0   15  19  6  258   2         1948
# 16         NaN                  0.0   15  14  1  107  11         1948
# 57         NaN                  0.0    5   6  3   51   0         1893
#
#     Final_Year Country  Highest_inn_score Out_Notout
# 9         1958      WI                207        Out
# 16        1960      WI                220        Out
# 57        1905     ENG                144     Notout

# %%
df["Balls_Faced"] = df["Balls_Faced"].fillna(0)

# %%
df[df["Balls_Faced"].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Match, Inns, Not_Outs, Runs, Highest_inns_score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie_Year, Final_Year, Country, Highest_inn_score, Out_Notout]
# Index: []

# %%
df["Balls_Faced"] = df["Balls_Faced"].astype("int")

# %%
df.isnull().sum()
# Out:
# Player                 0
# Match                  0
# Inns                   0
# Not_Outs               0
# Runs                   0
# Highest_inns_score     0
# Ave                    0
# Balls_Faced            0
# Batting_Strike_Rate    0
# 100                    0
# 50                     0
# 0                      0
# 4s                     0
# 6s                     0
# Rookie_Year            0
# Final_Year             0
# Country                0
# Highest_inn_score      0
# Out_Notout             0
# dtype: int64

# %%
df.dtypes
# Out:
# Player                  object
# Match                    int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_inns_score      object
# Ave                    float64
# Balls_Faced              int32
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie_Year              int32
# Final_Year               int32
# Country                 object
# Highest_inn_score        int64
# Out_Notout              object
# dtype: object

# %%
#Drop redundent columns
df.drop(columns = ["Highest_inns_score"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 2
#       1 #Drop redundent columns
# ----> 2 df.drop(columns = ["Highest_inns_score"], inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
# ...

# %%
df.head()
# Out:
#         Player  Match  Inns  Not_Outs  Runs    Ave  Balls_Faced  \
# 0  DG Bradman      52    80        10  6996  99.94         9800
# 1    HC Brook      12    20         1  1181  62.15         1287
# 2    AC Voges      20    31         7  1485  61.87         2667
# 3  RG Pollock      23    41         4  2256  60.97         1707
# 5  GA Headley      22    40         4  2190  60.83          416
#
#    Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  Final_Year Country  \
# 0                58.60   29  13  7  626   6         1928        1948     AUS
# 1                91.76    4   7  1  141  23         2022        2023     ENG
# 2                55.68    5   4  2  186   5         2015        2016     AUS
# 3                54.48    7  11  1  246  11         1963        1970      SA
# 5                56.00   10   5  2  104   1         1930        1954      WI
#
#    Highest_inn_score Out_Notout
# 0                334        Out
# 1                186        Out
# ...

# %%
##WUSTION Build the career_length column
#hint convert rookie_year/final_year and subtract

# %%
df["career_length"] = df["Final_Year"] - df["Rookie_Year"]

# %%
df.head()
# Out:
#         Player  Match  Inns  Not_Outs  Runs    Ave  Balls_Faced  \
# 0  DG Bradman      52    80        10  6996  99.94         9800
# 1    HC Brook      12    20         1  1181  62.15         1287
# 2    AC Voges      20    31         7  1485  61.87         2667
# 3  RG Pollock      23    41         4  2256  60.97         1707
# 5  GA Headley      22    40         4  2190  60.83          416
#
#    Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  Final_Year Country  \
# 0                58.60   29  13  7  626   6         1928        1948     AUS
# 1                91.76    4   7  1  141  23         2022        2023     ENG
# 2                55.68    5   4  2  186   5         2015        2016     AUS
# 3                54.48    7  11  1  246  11         1963        1970      SA
# 5                56.00   10   5  2  104   1         1930        1954      WI
#
#    Highest_inn_score Out_Notout  career_length
# 0                334        Out             20
# ...

# %%
##calculations with the dataframe

# %%
#Question 1 ->  Cricketers in this DF what is the average career length

# %%
df["career_length"].mean()
# Out:
# 13.193548387096774

# %%
#QUESTION 2 -> Average batting_strike_rate for cricketers who played over 10 years

# %%
df[df["career_length"]>10]["Batting_Strike_Rate"].mean()
# Out:
# 47.94681818181819

# %%
#second method
filter_df = df.loc[df["career_length"]>10]
filter_df["Batting_Strike_Rate"].mean()
# Out:
# 47.94681818181819

# %%
#third method
filter_dfquery = df.query("career_length > 10")
filter_dfquery["Batting_Strike_Rate"].mean()
# Out:
# 47.94681818181819

# %%
#QUESITON 3 -> find number of Cricketrs who played before 1960

# %%
df[df["Final_Year"] < 1960]
# Out:
#              Player  Match  Inns  Not_Outs  Runs    Ave  Balls_Faced  \
# 0       DG Bradman      52    80        10  6996  99.94         9800
# 5       GA Headley      22    40         4  2190  60.83          416
# 6      H Sutcliffe      54    84         9  4555  60.73         6558
# 7        E Paynter      20    31         5  1540  59.23         1288
# 9        ED Weekes      48    81         5  4455  58.61            0
# 10      WR Hammond      85   140        16  7249  58.45         7491
# 15        JB Hobbs      61   102         7  5410  56.94         5363
# 18        L Hutton      79   138        15  6971  56.67         2844
# 20    GE Tyldesley      14    20         2   990  55.00          178
# 25       AD Nourse      34    62         7  2960  53.81          108
# 33         J Ryder      20    32         5  1394  51.62         2035
# 44     DCS Compton      78   131        15  5807  50.06         2731
# 50         CP Mead      17    26         2  1185  49.37          619
# ...

# %%
#QUESTION 4 -> Max  Highest inns score by country

# %%
df.groupby(["Country"])["Highest_inn_score"].max().to_frame("Score").sort_values("Score", ascending = False)
# Out:
#          Score
# Country
# ICC/WI     400
# AUS        380
# SL         374
# WI         365
# ENG        364
# ICC/PAK    329
# ICC/IND    319
# PAK        313
# SA         278
# ICC/SA     277
# IND        254
# NZ         251
# ZIM        232

# %%
#QUESTIOIN 5 -> hundreds, Fifties, ducks (0) avg by country

# %%
df.groupby(["Country"])[["100", "50", "0"]].mean().sort_values(["100", "50", "0"], ascending = False)
# Out:
#                100         50          0
# Country
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# ICC/IND  29.500000  47.500000  12.000000
# IND      29.500000  36.500000  10.750000
# SL       28.666667  44.000000  12.333333
# ICC/PAK  25.000000  46.000000  15.000000
# PAK      21.250000  28.000000   9.500000
# AUS      20.625000  28.375000   8.562500
# NZ       18.500000  22.000000   6.000000
# WI       16.625000  25.625000   7.250000
# ENG      12.384615  20.846154   4.307692
# ZIM      12.000000  27.000000   5.000000
# SA        9.800000  20.200000   3.400000
