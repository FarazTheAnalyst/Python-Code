# %% [markdown]
# ### load Necessary Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ### Real World Examples

# %% [markdown]
# #### Line Graph

# %%
gas = pd.read_csv(r"C:\Users\Dell\Downloads\gas_prices.csv")
gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
plt.figure(figsize=(8, 5))

# plt.plot(gas.Year, gas.USA, "g.-", label='USA')
# plt.plot(gas.Year, gas.Canada, "y.-", label="Canada")
# plt.plot(gas["Year"], gas["South Korea"], "r.-", label="South Korea")
# plt.plot(gas.Year, gas.Australia, "b.-", label="Australia")

countries_to_look_at = ["Australia", "USA", "Canada", "South korea"]
for country in gas.columns:
    if country in countries_to_look_at:
        plt.plot(gas['Year'], gas[country], marker=".", label=country)


plt.title("Gas Prices over time in (USD)")
plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel("Year")
plt.ylabel("USD")

plt.legend(loc="center left", bbox_to_anchor=(0.4, 0.9))

plt.savefig("Gas_price_fig.png", dpi=300)

plt.show()

# %% [markdown]
# ### Load Fifa Data

# %%
fifa = pd.read_csv(r"C:\Users\Dell\Downloads\fifa_data.csv")
pd.options.display.max_columns = None
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %% [markdown]
# ### Histograms

# %%
bins = [40, 50, 60, 70, 80, 90, 100]

plt.hist(fifa.Overall, bins=bins, color = "#03fcec")

plt.xticks(bins)

plt.ylabel("Number of Players")
plt.xlabel("Skill level")
plt.title("Distribution of Player skills in fifa")

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
left = fifa.loc[fifa["Preferred Foot"] == "Left"].count()[0]
right = fifa.loc[fifa["Preferred Foot"] == "Right"].count()[0]

labels = ["left", "right"]
colors = ["#f5c842", "#b244f2"]
plt.pie([left, right], labels = labels, colors = colors, autopct="%.2f %%")

plt.title("Foot Preference of Fifa Players")

plt.show()

# %%
fifa.Weight = [int(x.strip("lbs")) if type(x)==str else x for x in fifa.Weight]

plt.style.use("ggplot")
light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 150)].count()[0]
medium = fifa.loc[(fifa.Weight >= 150) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 200)].count()[0]
heavy = fifa[(fifa.Weight >=200)].count()[0]

weights = [light, light_medium, medium, medium_heavy, heavy]
labels = ["under 125", "125-175", "150-175", "175-200", "Over 200"]
explode = [0.5, 0.2, 0, 0.1, 0.2]

plt.title("Weight Distribution of Fifa Players( in lbs)", fontdict={"fontname":"Comic Sans MS", "fontsize":10})
plt.pie(weights, labels=labels, explode=explode, pctdistance=0.8, autopct = "%.2f %%")

plt.show()

# %% [markdown]
# ### Box Plot

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa[fifa.Club.str.match("R") == 1]["Club"]
# Out:
# 6                 Real Madrid
# 8                 Real Madrid
# 11                Real Madrid
# 19                Real Madrid
# 27                Real Madrid
#                  ...
# 17605    RC Strasbourg Alsace
# 17733              Randers FC
# 17750              Randers FC
# 17751            Rosenborg BK
# 17890              Randers FC
# Name: Club, Length: 909, dtype: object

# %%
fifa.loc[fifa.Club.str.match("New En") == 1]["Club"].head()
# Out:
# 3008    New England Revolution
# 4219    New England Revolution
# 4957    New England Revolution
# 5070    New England Revolution
# 5201    New England Revolution
# Name: Club, dtype: object

# %%
plt.style.use('fivethirtyeight')

barcelona = fifa.loc[(fifa["Club"] == "FC Barcelona")]["Overall"]
real_madrid = fifa.loc[(fifa["Club"] == "Real Madrid")]["Overall"]
revs = fifa.loc[(fifa["Club"] == "New England Revolution")]["Overall"]

labels = ["Barcelona", "Real Mardrid", "New Revolution"]

boxes = plt.boxplot([barcelona, real_madrid, revs], labels=labels, patch_artist=True, medianprops={"linewidth":2})

plt.title("Professional Soccer Team Comparisons")
plt.ylabel("Fifa Overall Rating")

for box in boxes["boxes"]:
    #set edge color
    box.set(color="#4286f4", linewidth=2)
    #Change fill color
    box.set(facecolor="#e0e0e0")

plt.show()
