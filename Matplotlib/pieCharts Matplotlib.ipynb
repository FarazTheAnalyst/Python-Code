# %%
from matplotlib import pyplot as plt

# %%
plt.style.use("fivethirtyeight")

# %%
slices = [120, 80, 30, 20]
labels = ["sixty", "fourth", "Extra1", "Extra2"]
colors = ["purple", "lightgray", "skyblue", "navy"]

plt.pie(slices, labels=labels, colors=colors, wedgeprops={"edgecolor":"black"})
# Out:
# ([<matplotlib.patches.Wedge at 0x1f0ca47aed0>,
#   <matplotlib.patches.Wedge at 0x1f0ca48c6d0>,
#   <matplotlib.patches.Wedge at 0x1f0ca48dd90>,
#   <matplotlib.patches.Wedge at 0x1f0ca48f410>],
#  [Text(0.0690696084852792, 1.0978293989430645, 'sixty'),
#   Text(-0.7011664649040888, -0.8475645040313471, 'fourth'),
#   Text(0.7011662863559625, -0.8475646517391985, 'Extra1'),
#   Text(1.0654414403595847, -0.27355901952685396, 'Extra2')])

# %%
# Language Popularity
slices = [59219, 55466, 47544, 36443, 35917]
labels = ['JavaScript', 'HTML/CSS', 'SQL', 'Python', 'Java']
explode = [0, 0, 0, 0.1, 0]

# %%
plt.pie(slices, labels=labels, explode=explode,
        shadow=True,
        startangle=90,
        autopct="%1.1f%%",
        wedgeprops={"edgecolor":"black"}
       )
# Out:
# ([<matplotlib.patches.Wedge at 0x1f0cf7bdb50>,
#   <matplotlib.patches.Wedge at 0x1f0ca4f3290>,
#   <matplotlib.patches.Wedge at 0x1f0cf7bf8d0>,
#   <matplotlib.patches.Wedge at 0x1f0cf7d5a50>,
#   <matplotlib.patches.Wedge at 0x1f0cf7d7990>],
#  [Text(-0.7837501906172629, 0.7718391274789094, 'JavaScript'),
#   Text(-0.7987513829484706, -0.7563043225037827, 'HTML/CSS'),
#   Text(0.5906400253912186, -0.9279786422142812, 'SQL'),
#   Text(1.191260634749693, 0.1445617518424518, 'Python'),
#   Text(0.508929586614865, 0.9751875080557701, 'Java')],
#  [Text(-0.42750010397305244, 0.4210031604430415, '25.2%'),
#   Text(-0.4356825725173476, -0.4125296304566087, '23.6%'),
#   Text(0.3221672865770283, -0.5061701684805169, '20.3%'),
#   Text(0.6949020369373209, 0.08432768857476353, '15.5%'),
#   Text(0.27759795633538087, 0.5319204589395109, '15.3%')])
